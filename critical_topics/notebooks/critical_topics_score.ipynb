# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/drive/My Drive/IBM_sentiment_analysis/data/labelled_positivity_score.csv')
print(df.shape)
print(df.isnull().sum())
df.head()
# Out:
# (4185573, 4)
# date         0
# text         0
# cleaned      0
# sentiment    0
# dtype: int64
#          date  ... sentiment
# 0  2020-03-01  ...   -0.5423
# 1  2020-03-01  ...    0.0000
# 2  2020-03-01  ...    0.0000
# 3  2020-03-01  ...   -0.8591
# 4  2020-03-01  ...   -0.8020
#
# [5 rows x 4 columns]

# %%
searchfor = ['pm care', 'pm care fund','care fund','pmcarefund','pmcare','carefund','pm cares fund','pmcaresfund','pm cares','cares fund','caresfund','pmcares','relief fund','relieffund','pmrelieffund','pm relief funds','pmrelieffunds','relieffunds']

# %%
df1=df[df['cleaned'].str.contains('|'.join(searchfor))]
print(df1.shape)
print(df1.isnull().sum())
df1.head()
# Out:
# (32614, 4)
# date         0
# text         0
# cleaned      0
# sentiment    0
# dtype: int64
#              date  ... sentiment
# 13971  2020-03-02  ...    0.9153
# 14579  2020-03-02  ...    0.9674
# 18523  2020-03-02  ...    0.9274
# 39919  2020-03-04  ...   -0.4019
# 52629  2020-03-04  ...    0.4588
#
# [5 rows x 4 columns]

# %%
df2=df1.reset_index(drop=True)
print(df2.shape)
df2.head()
# Out:
# (32614, 4)
#          date  ... sentiment
# 0  2020-03-02  ...    0.9153
# 1  2020-03-02  ...    0.9674
# 2  2020-03-02  ...    0.9274
# 3  2020-03-04  ...   -0.4019
# 4  2020-03-04  ...    0.4588
#
# [5 rows x 4 columns]

# %%
len(df2['date'].unique())
# Out:
# 64

# %%
import datetime
full=[]
summ=0
start_date = datetime.date(2020, 2, 1)
end_date = datetime.date(2020, 4, 30)
delta = datetime.timedelta(days=1)
while start_date <= end_date:
    temp=df2[df2['date']==str(start_date)]
    score=0
    count=0
    for index,row in temp.iterrows():
      score=score+row['sentiment']
      count=count+1
    if(count==0):
      row=[start_date,score,count,0]
    else:
      row=[start_date,score,count,(score/count)]
    full.append(row)
    summ=summ+count
    start_date += delta
    print(start_date)
# Out:
# 2020-02-02
# 2020-02-03
# 2020-02-04
# 2020-02-05
# 2020-02-06
# 2020-02-07
# 2020-02-08
# 2020-02-09
# 2020-02-10
# 2020-02-11
# 2020-02-12
# 2020-02-13
# 2020-02-14
# 2020-02-15
# 2020-02-16
# 2020-02-17
# 2020-02-18
# 2020-02-19
# 2020-02-20
# 2020-02-21
# 2020-02-22
# 2020-02-23
# 2020-02-24
# 2020-02-25
# 2020-02-26
# 2020-02-27
# 2020-02-28
# 2020-02-29
# 2020-03-01
# 2020-03-02
# 2020-03-03
# 2020-03-04
# 2020-03-05
# 2020-03-06
# 2020-03-07
# 2020-03-08
# 2020-03-09
# 2020-03-10
# 2020-03-11
# 2020-03-12
# 2020-03-13
# 2020-03-14
# 2020-03-15
# 2020-03-16
# 2020-03-17
# 2020-03-18
# 2020-03-19
# 2020-03-20
# 2020-03-21
# 2020-03-22
# 2020-03-23
# 2020-03-24
# 2020-03-25
# 2020-03-26
# 2020-03-27
# 2020-03-28
# 2020-03-29
# 2020-03-30
# 2020-03-31
# 2020-04-01
# 2020-04-02
# 2020-04-03
# 2020-04-04
# 2020-04-05
# 2020-04-06
# 2020-04-07
# 2020-04-08
# 2020-04-09
# 2020-04-10
# 2020-04-11
# 2020-04-12
# 2020-04-13
# 2020-04-14
# 2020-04-15
# 2020-04-16
# 2020-04-17
# ...

# %%
print(summ)
# Out:
# 32614

# %%
dff=pd.DataFrame(full,columns=['date','total_score','count','normalised_score'])
print(dff.shape)
print(dff.isnull().sum())
dff.head()
# Out:
# (90, 4)
# date                0
# total_score         0
# count               0
# normalised_score    0
# dtype: int64
#          date  total_score  count  normalised_score
# 0  2020-02-01       0.0000      0            0.0000
# 1  2020-02-02       0.0000      0            0.0000
# 2  2020-02-03       0.0000      0            0.0000
# 3  2020-02-04       0.5411      1            0.5411
# 4  2020-02-05       0.8176      1            0.8176

# %%
dff.to_csv('/content/drive/My Drive/IBM_sentiment_analysis/critical_topics/score_plots/carefund_score.csv',index=False)
