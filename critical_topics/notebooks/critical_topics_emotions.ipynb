# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/drive/My Drive/IBM_sentiment_analysis/classification_sentiment_analysis/data/labelled_emotions(fear,anger,sadness,joy,neutral).csv')
print(df.shape)
print(df.isnull().sum())
df.head()
# Out:
# (4185573, 6)
# Unnamed: 0        0
# date              0
# text              0
# retweet_count    64
# emotion           0
# cleaned           0
# dtype: int64
#    Unnamed: 0  ...                                            cleaned
# 0           0  ...  bpcl retail outlets feeding migrantlabour stra...
# 1           1  ...  printmedia next film rrr wil mahesh lockdown d...
# 2           2  ...  printaa forlorn markets mosques first day ramz...
# 3           3  ...                            one best tweets century
# 4           4  ...  tajammul pasha muzammil pasha karnataka 's kol...
#
# [5 rows x 6 columns]

# %%
searchfor = ['worker','migrant','labourer','job']

# %%
df1=df[df['cleaned'].str.contains('|'.join(searchfor))]
print(df1.shape)
print(df1.isnull().sum())
df1.head()
# Out:
# (132692, 6)
# Unnamed: 0       0
# date             0
# text             0
# retweet_count    1
# emotion          0
# cleaned          0
# dtype: int64
#      Unnamed: 0  ...                                            cleaned
# 0             0  ...  bpcl retail outlets feeding migrantlabour stra...
# 9             9  ...  india initiative feeding daily wages labourer ...
# 153         153  ...                        corona relif health workers
# 183         183  ...  assam youth congress committee distributed rat...
# 204         204  ...  pakistan health workers including doctors cont...
#
# [5 rows x 6 columns]

# %%
df2=df1.iloc[:,1:]
df2=df2.reset_index(drop=True)
print(df2.shape)
df2.head()
# Out:
# (132692, 5)
#          date  ...                                            cleaned
# 0  2020-04-25  ...  bpcl retail outlets feeding migrantlabour stra...
# 1  2020-04-25  ...  india initiative feeding daily wages labourer ...
# 2  2020-04-25  ...                        corona relif health workers
# 3  2020-04-25  ...  assam youth congress committee distributed rat...
# 4  2020-04-25  ...  pakistan health workers including doctors cont...
#
# [5 rows x 5 columns]

# %%
len(df2['date'].unique())
# Out:
# 90

# %%
import datetime
full=[]
summ=0
start_date = datetime.date(2020, 2, 1)
end_date = datetime.date(2020, 4, 30)
delta = datetime.timedelta(days=1)
while start_date <= end_date:
    temp=df2[df2['date']==str(start_date)]
    n=temp[temp['emotion']=='neutral']
    s=temp[temp['emotion']=='sadness']
    a=temp[temp['emotion']=='anger']
    j=temp[temp['emotion']=='joy']
    f=temp[temp['emotion']=='fear']
    nc=n.shape[0]
    sc=s.shape[0]
    ac=a.shape[0]
    jc=j.shape[0]
    fc=f.shape[0]
    total=nc+sc+ac+jc+fc
    if(total!=0):
      ncp=(nc/total)*100
      scp=(sc/total)*100
      acp=(ac/total)*100
      jcp=(jc/total)*100
      fcp=(fc/total)*100
    else:
      ncp=0
      scp=0
      acp=0
      jcp=0
      fcp=0

    row=[start_date,nc,sc,ac,jc,fc,total,ncp,scp,acp,jcp,fcp]
    full.append(row)
    summ=summ+nc+sc+ac+jc+fc
    start_date += delta
    print(start_date)
# Out:
# 2020-02-02
# 2020-02-03
# 2020-02-04
# 2020-02-05
# 2020-02-06
# 2020-02-07
# 2020-02-08
# 2020-02-09
# 2020-02-10
# 2020-02-11
# 2020-02-12
# 2020-02-13
# 2020-02-14
# 2020-02-15
# 2020-02-16
# 2020-02-17
# 2020-02-18
# 2020-02-19
# 2020-02-20
# 2020-02-21
# 2020-02-22
# 2020-02-23
# 2020-02-24
# 2020-02-25
# 2020-02-26
# 2020-02-27
# 2020-02-28
# 2020-02-29
# 2020-03-01
# 2020-03-02
# 2020-03-03
# 2020-03-04
# 2020-03-05
# 2020-03-06
# 2020-03-07
# 2020-03-08
# 2020-03-09
# 2020-03-10
# 2020-03-11
# 2020-03-12
# 2020-03-13
# 2020-03-14
# 2020-03-15
# 2020-03-16
# 2020-03-17
# 2020-03-18
# 2020-03-19
# 2020-03-20
# 2020-03-21
# 2020-03-22
# 2020-03-23
# 2020-03-24
# 2020-03-25
# 2020-03-26
# 2020-03-27
# 2020-03-28
# 2020-03-29
# 2020-03-30
# 2020-03-31
# 2020-04-01
# 2020-04-02
# 2020-04-03
# 2020-04-04
# 2020-04-05
# 2020-04-06
# 2020-04-07
# 2020-04-08
# 2020-04-09
# 2020-04-10
# 2020-04-11
# 2020-04-12
# 2020-04-13
# 2020-04-14
# 2020-04-15
# 2020-04-16
# 2020-04-17
# ...

# %%
print(summ)
# Out:
# 132692

# %%
dff=pd.DataFrame(full,columns=['date','neutral_count','sadness_count','anger_count','joy_count','fear_count','total_count','neutral_count_pct','sadness_count_pct','anger_count_pct','joy_count_pct','fear_count_pct'])
print(dff.shape)
print(dff.isnull().sum())
dff.head()
# Out:
# (90, 12)
# date                 0
# neutral_count        0
# sadness_count        0
# anger_count          0
# joy_count            0
# fear_count           0
# total_count          0
# neutral_count_pct    0
# sadness_count_pct    0
# anger_count_pct      0
# joy_count_pct        0
# fear_count_pct       0
# dtype: int64
#          date  neutral_count  ...  joy_count_pct  fear_count_pct
# 0  2020-02-01             40  ...      26.470588        4.411765
# 1  2020-02-02            121  ...      13.513514        2.702703
# 2  2020-02-03             78  ...       2.352941        1.176471
# 3  2020-02-04             51  ...       3.333333        5.000000
# 4  2020-02-05             47  ...       0.000000        0.000000
#
# [5 rows x 12 columns]

# %%
dff.to_csv('/content/drive/My Drive/IBM_sentiment_analysis/critical_topics/emotion_plots/workers_emotion.csv',index=False)
